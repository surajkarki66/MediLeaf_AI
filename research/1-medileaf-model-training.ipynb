# %% [markdown]
# # Training

# %% [markdown]
# ## 1. Clone Repo

# %%
# !git clone https://github.com/surajkarki66/MediLeaf_AI.git
# Out:
# Cloning into 'MediLeaf_AI'...
# remote: Enumerating objects: 538, done.
# remote: Counting objects: 100% (538/538), done.
# remote: Compressing objects: 100% (302/302), done.
# remote: Total 538 (delta 271), reused 440 (delta 178), pack-reused 0
# Receiving objects: 100% (538/538), 20.97 MiB | 29.95 MiB/s, done.
# Resolving deltas: 100% (271/271), done.

# %% [markdown]
# ## 2. Install dependencies

# %%
# !cd MediLeaf_AI && pip install -r requirements.txt
# Out:
# Obtaining file:///kaggle/working/MediLeaf_AI (from -r requirements.txt (line 17))
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.6/452.6 kB 15.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 57.1 MB/s eta 0:00:00ta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.0/426.0 kB 19.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.6/46.6 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 52.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 kB 11.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## 3. Run the script

# %%
# !cd MediLeaf_AI && dvc repro
# Out:
# Running stage 'data_ingestion':
# > python src/MediLeaf_AI/pipeline/stage_01_data_ingestion.py
#   0% Committing artifacts/data_ingestion/dataset_v2 to cache| |4.97k/? [00:01<00
# !
#   0%|          |memory://.1rr8BoD61_QDC70_-L8XmA0.00/480k [00:00<?,        ?B/s]
# Generating lock file 'dvc.lock'
# Updating lock file 'dvc.lock'
#
# Running stage 'prepare_base_model':
# > python src/MediLeaf_AI/pipeline/stage_02_prepare_base_model.py
# 2024-07-09 16:26:39.701422: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-09 16:26:39.701583: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...
